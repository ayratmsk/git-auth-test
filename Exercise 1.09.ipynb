# %% [markdown]
# ***Exercise 1.09***
#
# In this exercise will walk us through all of the steps necessary to get started with Git
# and GitHub. If you do not have any experience working with version control yet, this
# exercise will be beneficial to you.

# %%
def add_elements(a,b):
    result = []
    for i, j in zip(a,b):
       result.append(i + j)
    
    return result

# %%
with open('input.txt', 'r') as f:
    lines = f.readlines()

last_line1, last_line2 = lines[-2], lines[-1]

# %%
list1 = list(map(int, last_line1[: -1].split(',')))
list2 = list(map(int, last_line2[: -1].split(',')))

# %%
new_list = add_elements(list1, list2)

with open('input.txt', 'a') as f:
    for index, item in enumerate(new_list):
        f.write(str(item))
    
        if index < len(new_list) - 1:
            f.write(',')
        else:
            f.write('\n')
